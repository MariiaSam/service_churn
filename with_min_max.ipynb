# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from joblib import dump

# %%
df = pd.read_csv('data/internet_service_churn.csv')  # Завантаження датасету
df
# Out:
#             id  is_tv_subscriber  is_movie_package_subscriber  \
# 0           15                 1                            0
# 1           18                 0                            0
# 2           23                 1                            0
# 3           27                 0                            0
# 4           34                 0                            0
# ...        ...               ...                          ...
# 72269  1689648                 1                            1
# 72270  1689676                 1                            0
# 72271  1689679                 1                            0
# 72272  1689733                 0                            0
# 72273  1689744                 1                            1
#
#        subscription_age  bill_avg  reamining_contract  service_failure_count  \
# 0                 11.95        25                0.14                      0
# 1                  8.22         0                 NaN                      0
# 2                  8.91        16                0.00                      0
# 3                  6.87        21                 NaN                      1
# 4                  6.39         0                 NaN                      0
# ...                 ...       ...                 ...                    ...
# 72269              0.09         0                1.25                      0
# 72270              0.06         1                1.63                      0
# 72271              0.02         0                2.19                      0
# 72272              0.01         0                0.72                      0
# 72273              0.01         0                0.82                      0
#
#        download_avg  upload_avg  download_over_limit  churn
# 0               8.4         2.3                    0      0
# 1               0.0         0.0                    0      1
# 2              13.7         0.9                    0      1
# 3               0.0         0.0                    0      1
# 4               0.0         0.0                    0      1
# ...             ...         ...                  ...    ...
# 72269           0.0         0.0                    0      1
# 72270           0.8         0.0                    0      1
# 72271           1.5         0.2                    0      1
# 72272           0.0         0.0                    0      1
# 72273           0.0         0.0                    0      1
#
# [72274 rows x 11 columns]

# %% [markdown]
# ### Заповнення порожніх значень модою (оскільки у файлі EDA на гістограмах цих колонок видна чітка мода)

# %%
df['reamining_contract'] = df['reamining_contract'].fillna(df['reamining_contract'].mode()[0])
df = df.fillna({'download_avg':df['download_avg'].mode()[0]})
df = df.fillna({'upload_avg':df['upload_avg'].mode()[0]})

# %% [markdown]
# ### Нормалізація даних

# %%
df
# Out:
#             id  is_tv_subscriber  is_movie_package_subscriber  \
# 0           15                 1                            0
# 1           18                 0                            0
# 2           23                 1                            0
# 3           27                 0                            0
# 4           34                 0                            0
# ...        ...               ...                          ...
# 72269  1689648                 1                            1
# 72270  1689676                 1                            0
# 72271  1689679                 1                            0
# 72272  1689733                 0                            0
# 72273  1689744                 1                            1
#
#        subscription_age  bill_avg  reamining_contract  service_failure_count  \
# 0                 11.95        25                0.14                      0
# 1                  8.22         0                0.00                      0
# 2                  8.91        16                0.00                      0
# 3                  6.87        21                0.00                      1
# 4                  6.39         0                0.00                      0
# ...                 ...       ...                 ...                    ...
# 72269              0.09         0                1.25                      0
# 72270              0.06         1                1.63                      0
# 72271              0.02         0                2.19                      0
# 72272              0.01         0                0.72                      0
# 72273              0.01         0                0.82                      0
#
#        download_avg  upload_avg  download_over_limit  churn
# 0               8.4         2.3                    0      0
# 1               0.0         0.0                    0      1
# 2              13.7         0.9                    0      1
# 3               0.0         0.0                    0      1
# 4               0.0         0.0                    0      1
# ...             ...         ...                  ...    ...
# 72269           0.0         0.0                    0      1
# 72270           0.8         0.0                    0      1
# 72271           1.5         0.2                    0      1
# 72272           0.0         0.0                    0      1
# 72273           0.0         0.0                    0      1
#
# [72274 rows x 11 columns]

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df.iloc[:, 3:10])  # За для оптимізації, скейлимо тільки колонки з числовими значеннями (колонки з boolean(0 або 1) не чіпаємо)

# %%
df.iloc[:, 3:10] = scaled_df
df = pd.DataFrame(df, columns=df.columns)   # Перетворення відскейленої матриці даних назад у pandas dataframe
df.head()
# Out:
# C:\Users\4atty\AppData\Local\Temp\ipykernel_34432\3564032686.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.06157635 0.         0.03940887 ... 0.         0.         0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 3:10] = scaled_df
# C:\Users\4atty\AppData\Local\Temp\ipykernel_34432\3564032686.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 3:10] = scaled_df
# C:\Users\4atty\AppData\Local\Temp\ipykernel_34432\3564032686.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:, 3:10] = scaled_df
#    id  is_tv_subscriber  is_movie_package_subscriber  subscription_age  \
# 0  15                 1                            0          0.933697
# 1  18                 0                            0          0.642746
# 2  23                 1                            0          0.696568
# 3  27                 0                            0          0.537441
# 4  34                 0                            0          0.500000
#
#    bill_avg  reamining_contract  service_failure_count  download_avg  \
# 0  0.061576            0.047945               0.000000      0.001903
# 1  0.000000            0.000000               0.000000      0.000000
# 2  0.039409            0.000000               0.000000      0.003103
# 3  0.051724            0.000000               0.052632      0.000000
# 4  0.000000            0.000000               0.000000      0.000000
#
#    upload_avg  download_over_limit  churn
# 0    0.005074                  0.0      0
# 1    0.000000                  0.0      1
# 2    0.001985                  0.0      1
# 3    0.000000                  0.0      1
# 4    0.000000                  0.0      1

# %%
df.to_csv('data/mode_and_minmax.csv', index=False)   # Створення csv файлу

# %%
dump(scaled_df, 'scaled.joblib')
# Out:
# ['scaled.joblib']
